# %%
import random
print("--------------------INSTRUCTIONS--------------------")
print("1. Choose ODD or EVEN \n2. Enter your input for Toss between 1 to 10 \n3. If you win the toss, Opt Bat or Ball \n4. If Number matches then it's OUT")
print("----------------------------------------------------")
def playagain():
    q=input("Play Again ???")
    if q.upper()=="YES":
        main()
    elif  q.upper()=="NO" :
        exit()
    else:
        print('-----Invalid input-----\n-----Please try again-----')
        playagain()
 
def main():
   
    
    def bat1():  
        print('You\'re all set to Bat now... ')
        total = 0
        while (True):
 
            match = random.randint(1, 10)
            computer = random.randint(1, 10)
            player = int(input("BAT: "))
            if player>10:
                print('INVALID INPUT... GAME RESTARTING...')
                toss()
            print("AI Bowls: ", computer)
            total = total + player
            
            if total == 0:
                print("GOLDEN DUCK..!!")
            if total in (50,59):
                print("- - - - - - H A L F  C E N T U R Y - - - - - -")

            if total in (100,110):
                print("- - - - - -  C E N T U R Y - - - - - -")
            if total in (200,210):
                print("- - - - - - D O U B L E  C E N T U R Y - - - - - -")
 
            if (computer == player):
                print("OUT...!!!")
                print("Your total runs =", total)
                break
 
        print('AI need ', total+1, 'runs to win!')
 
        print('AI Ready to chase..!!!')
        ctotal = 0
        while (True):
 
            cmatch = random.randint(1, 10)
            computer = random.randint(1, 10)
            player = int(input("BOWL: "))
            if player>10:
                print('INVALID INPUT... GAME RESTARTING...')
                toss()
            print("Computer plays: ", computer)
            ctotal = ctotal + computer
            
            if ctotal > total:
                    print("AI Score =", ctotal)
                    print('AI Wins')
            break
            if ctotal == 0:
                print("GOLDEN DUCK..!!")
            if ctotal in (50,59):
                print("- - - - - - H A L F  C E N T U R Y - - - - - -")

            if ctotal in (100,110):
                print("- - - - - -  C E N T U R Y - - - - - -")
            if ctotal in (200,210):
                print("- - - - - - D O U B L E  C E N T U R Y - - - - - -")
            if ctotal>total:
                break
            if (computer == player):
                print("Number Matched! ..out!!!")
                print("computer's total runs =", ctotal)

                if total>ctotal:
                    print('you win!')
                else:
                    print('tie!')
                break

            
    def bat2():
        print('it is computers time to bat.')
        ctotal = 0
        while (True):
 
            cmatch = random.randint(1, 10)
            computer = random.randint(1, 10)
            player = int(input("put your ball: "))
            if player>10:
                print('INVALID INPUT... GAME RESTARTING...')
                toss()
            print("Computer plays: ", computer)
            ctotal = ctotal + computer
            
            if ctotal == 0:
                print("GOLDEN DUCK..!!")
            if ctotal in (50,59):
                print("- - - - - - H A L F  C E N T U R Y - - - - - -")

            if ctotal in (100,110):
                print("- - - - - -  C E N T U R Y - - - - - -")
            if ctotal in (200,210):
                print("- - - - - - D O U B L E  C E N T U R Y - - - - - -")
            
            if (computer == player):
                print("Number Matched! ..out!!!")
                print("computer's total runs =", ctotal)
                break
 
        print('The computer is bowling')
        total = 0
        while (True):
 
            match = random.randint(1, 10)
            computer = random.randint(1, 10)
            player = int(input("Play your shot: "))
            if player>10:
                print('u arent allowed to play any number more than 10.The game will restart now')
                toss()
            print("Computer plays: ", computer)
            total = total + player
            
                        
            if total == 0:
                print("GOLDEN DUCK..!!")
            if total in (50,59):
                print("- - - - - - H A L F  C E N T U R Y - - - - - -")

            if total in (100,110):
                print("- - - - - -  C E N T U R Y - - - - - -")
            if total in (200,210):
                print("- - - - - - D O U B L E  C E N T U R Y - - - - - -")
 
            if (computer == player):
                print("Number Matched! ..out!!!")
                print("Your total runs =", total)
                if ctotal>total:
                    print('you lose!')
                elif total>ctotal:
                    print('you win!')
                else:
                    print('tie!')
                break
 
    def toss():
        x=input('what do u want? (odd/eve):').lower()
        y=int(input('play your number for the toss(1/2):'))
        if y>10:
            print("Impossible Attempt, Try again")
            toss()
        z=random.randint(1,10)
        print('the computer has played',z,'for the toss')
        if x=='eve':
            if ((y+z)%2)==0:
                print('you have won the toss')
                a=input('BAT OR BALL ???')
                if a.upper() =='BAT':
                    bat1()
                elif a,upper() =='BALL':
                    bat2()
                else:
                    print('INVALID INPUT...GAME RESTARTING...')
                    toss()
            else:
                x=random.choice(['bat','bowl'])
                if x=='bat':
                    print('The computer chooses to bat!')
                    bat2()
                elif x=='bowl':
                    print('The computer chooses to bowl!')
                    bat1()
        elif x=='odd':
            if ((y+z)%2)==0:
                y=random.choice(['bat','bowl'])
                if y=='bat':
                    print('The computer chooses to bat!')
                    bat2()
                elif y=='bowl':
                    print('The computer chooses to bowl!')
                    bat1()
                
            else:
                print('You\'ve won the Toss..!!')
                a=input('What you want choose Bat or Ball')
                if a.upper()=='BAT':
                    bat1()
                elif a.upper()=='BOWL':
                    bat2()
                else:
                    print('GAME RESTARTING....')
                    toss()
        else:
             print('GAME RESTARTING....')
             toss()
  
 
    toss()
    playagain()
 
main()
# Out:
# --------------------INSTRUCTIONS--------------------
# 1. Choose ODD or EVEN
# 2. Enter your input for Toss between 1 to 10
# 3. If you win the toss, Opt Bat or Ball
# 4. If Number matches then it's OUT
# ----------------------------------------------------
# what do u want? (odd/eve):odd
# play your number for the toss(1/2):8
# the computer has played 8 for the toss
# The computer chooses to bowl!
# You're all set to Bat now...
# BAT: 8
# AI Bowls:  2
# BAT: 8
# AI Bowls:  6
# BAT: 8
# AI Bowls:  8
# OUT...!!!
# Your total runs = 24
# AI need  25 runs to win!
# AI Ready to chase..!!!
# BOWL: 9
# Computer plays:  5
# Play Again ???yes
# what do u want? (odd/eve):odd
# play your number for the toss(1/2):3
# the computer has played 6 for the toss
# You've won the Toss..!!
